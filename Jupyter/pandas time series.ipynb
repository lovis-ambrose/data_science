# %% [markdown]
# # Pandas time series Analysis
# # Datetimeindex
# Time series is a set of data point indexed in time order
# Datetime index and resampling

# %%
import pandas as pd

# %%
# read the apple's historical data and pass date as timestamp(date) not as a str
# the dataframe shows apple's prices
df=pd.read_csv("csv_files/aapl/aapl.csv", parse_dates=["Date"], index_col="Date")
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.238388
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  145.536606
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  144.572342
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.263840
# 2022-10-10  140.419998  141.889999  138.570007  140.419998  139.591873
# ...                ...         ...         ...         ...         ...
# 2023-09-27  172.619995  173.039993  169.050003  170.429993  170.429993
# 2023-09-28  169.339996  172.029999  167.619995  170.690002  170.690002
# 2023-09-29  172.020004  173.070007  170.339996  171.210007  171.210007
# 2023-10-02  171.220001  174.300003  170.929993  173.750000  173.750000
# 2023-10-03  172.259995  173.630005  170.820007  172.399994  172.399994
#
#               Volume
# Date
# 2022-10-04  87830100
# 2022-10-05  79471000
# 2022-10-06  68402200
# ...

# %%
# check for the index
df.index
# Out:
# DatetimeIndex(['2022-10-04', '2022-10-05', '2022-10-06', '2022-10-07',
#                '2022-10-10', '2022-10-11', '2022-10-12', '2022-10-13',
#                '2022-10-14', '2022-10-17',
#                ...
#                '2023-09-20', '2023-09-21', '2023-09-22', '2023-09-25',
#                '2023-09-26', '2023-09-27', '2023-09-28', '2023-09-29',
#                '2023-10-02', '2023-10-03'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %%
# retrieve Oct 2022 stock prices
df["2022-10-01":"2022-10-31"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-04  145.029999  146.220001  144.259995  146.100006  145.238388
# 2022-10-05  144.070007  147.380005  143.009995  146.399994  145.536606
# 2022-10-06  145.809998  147.539993  145.220001  145.429993  144.572342
# 2022-10-07  142.539993  143.100006  139.449997  140.089996  139.263840
# 2022-10-10  140.419998  141.889999  138.570007  140.419998  139.591873
# 2022-10-11  139.899994  141.350006  138.220001  138.979996  138.160370
# 2022-10-12  139.130005  140.360001  138.160004  138.339996  137.524155
# 2022-10-13  134.990005  143.589996  134.369995  142.990005  142.146744
# 2022-10-14  144.309998  144.520004  138.190002  138.380005  137.563919
# 2022-10-17  141.070007  142.899994  140.270004  142.410004  141.570160
# 2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011597
# ...

# %%
# find the average closing price of apple's stock for jan 2023
df["2023-01-01":"2023-01-31"].Close.mean()
# Out:
# 135.77899945000001

# %%
# retrieve the price on any given date
df["2023-05-10":"2023-05-10"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-10  173.020004  174.029999  171.899994  173.559998  173.086533
#
#               Volume
# Date
# 2023-05-10  53724500

# %%
# alternatively,,, retrieve the price on any given date
desired_date=pd.to_datetime("2023-05-10")
df.loc[df.index.date == desired_date.date()]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-05-10  173.020004  174.029999  171.899994  173.559998  173.086533
#
#               Volume
# Date
# 2023-05-10  53724500

# %% [markdown]
# # resampling

# %%
# retrieve monthly data eg mothly stock prices
# get the monthly average prices for close price
# first select the column, resample it
# use m for monthly freq, y for yearly freq, w for weekly, d for daily freq
df.Close.resample("M").mean()
# Out:
# Date
# 2022-10-31    145.141500
# 2022-11-30    145.843331
# 2022-12-31    137.876667
# 2023-01-31    135.778999
# 2023-02-28    150.968421
# 2023-03-31    154.964782
# 2023-04-30    165.045790
# 2023-05-31    172.622728
# 2023-06-30    184.283333
# 2023-07-31    192.411501
# 2023-08-31    181.083913
# 2023-09-30    177.002501
# 2023-10-31    173.074997
# Freq: M, Name: Close, dtype: float64

# %%
# import matplotlib.pyplot as plt
# plot the chart to show the trend
# plot is set to line by default, you can do hist, pie, bar, barh, box, or area
df.Close.resample("m").mean().plot(kind="line", title="Close prices \n", xlabel="Months per Year", ylabel="Average monthly Close Prices")
# plt.show()
# Out:
# <Axes: title={'center': 'Close prices \n'}, xlabel='Months per Year', ylabel='Average monthly Close Prices'>

# %%
# plot daily average close prices
# check doc for more date offset strings
df.Close.resample("d").mean().plot(kind="line", title="Close prices \n", xlabel="Months per Year", ylabel="Average monthly Close Prices")
# Out:
# <Axes: title={'center': 'Close prices \n'}, xlabel='Months per Year', ylabel='Average monthly Close Prices'>

# %%
df.Close.plot() # will plot basd on daily basis
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Date range in pandas with time series
# Lets deal with data whose date is missig

# %%
# read apple csv file
df1=pd.read_csv("csv_files/aapl/aapl_missed_date.csv")
df1
# Out:
#       Open   High    Low  Close     Volume
# 0    37.48  37.58  37.03  37.18   79383680
# 1    37.47  37.56  37.30  37.38   68854600
# 2    38.44  38.50  36.83  37.64  129905360
# 3    38.34  38.48  38.27  38.37   63123800
# 4    37.95  38.46  37.95  38.19   75415720
# ..     ...    ...    ...    ...        ...
# 247  26.57  26.91  26.55  26.87  162213592
# 248  26.40  26.50  26.32  26.47  109634600
# 249  26.20  26.46  26.19  26.45  120810564
# 250  26.51  26.52  26.00  26.12  135266236
# 251  26.10  26.54  26.10  26.51  152671484
#
# [252 rows x 5 columns]

# %%
# i want to generate dates to insert into the data frame
# we  date from 1s June 2020 to 18 may 2021, set freq="B" for only business days ie exclude weekends
# Note that the # of rows has to match the array length specified
dates= pd.date_range(start="6/01/2020", end="5/18/2021", freq="B")
dates
# Out:
# DatetimeIndex(['2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04',
#                '2020-06-05', '2020-06-08', '2020-06-09', '2020-06-10',
#                '2020-06-11', '2020-06-12',
#                ...
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-10',
#                '2021-05-11', '2021-05-12', '2021-05-13', '2021-05-14',
#                '2021-05-17', '2021-05-18'],
#               dtype='datetime64[ns]', length=252, freq='B')

# %%
# set the index of dataframe to the generated date
df1.set_index(dates, inplace=True)
df1
# Out:
#              Open   High    Low  Close     Volume
# 2020-06-01  37.48  37.58  37.03  37.18   79383680
# 2020-06-02  37.47  37.56  37.30  37.38   68854600
# 2020-06-03  38.44  38.50  36.83  37.64  129905360
# 2020-06-04  38.34  38.48  38.27  38.37   63123800
# 2020-06-05  37.95  38.46  37.95  38.19   75415720
# ...           ...    ...    ...    ...        ...
# 2021-05-12  26.57  26.91  26.55  26.87  162213592
# 2021-05-13  26.40  26.50  26.32  26.47  109634600
# 2021-05-14  26.20  26.46  26.19  26.45  120810564
# 2021-05-17  26.51  26.52  26.00  26.12  135266236
# 2021-05-18  26.10  26.54  26.10  26.51  152671484
#
# [252 rows x 5 columns]

# %%
# plot a line graph to show the monthly close dates
df1.Close.plot()
# Out:
# /home/lovis/.local/lib/python3.10/site-packages/matplotlib/axis.py:1732: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   ret = self.converter.convert(x, self.units, self)
# /home/lovis/.local/lib/python3.10/site-packages/matplotlib/axis.py:1732: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   ret = self.converter.convert(x, self.units, self)
# /home/lovis/.local/lib/python3.10/site-packages/matplotlib/axis.py:1484: FutureWarning: Period with BDay freq is deprecated and will be removed in a future version. Use a DatetimeIndex with BDay freq instead.
#   return self.major.locator()
# /home/lovis/.local/lib/python3.10/site-packages/matplotlib/axis.py:1484: FutureWarning: PeriodDtype[B] is deprecated and will be removed in a future version. Use a DatetimeIndex with freq='B' instead
#   return self.major.locator()
# ...

# %%
# we can now plot a line graph using the dates and close prices
import matplotlib.pyplot as plt
df1.Close.resample("M").mean().plot(kind="line", ylabel="Close prices", xlabel="Period", title="Apple Average Monthly close prices \n")
plt.show()

# %%
# the dataframe has no data for wekends. I want to fill the data to cater for them as well
# we use asfreq("D", method="pad"). padding will do forward filling. See dates 6 & 7
d_new=df1.asfreq("D", method="pad")
d_new.head(10)
# Out:
#              Open   High    Low  Close     Volume
# 2020-06-01  37.48  37.58  37.03  37.18   79383680
# 2020-06-02  37.47  37.56  37.30  37.38   68854600
# 2020-06-03  38.44  38.50  36.83  37.64  129905360
# 2020-06-04  38.34  38.48  38.27  38.37   63123800
# 2020-06-05  37.95  38.46  37.95  38.19   75415720
# 2020-06-06  37.95  38.46  37.95  38.19   75415720
# 2020-06-07  37.95  38.46  37.95  38.19   75415720
# 2020-06-08  37.65  38.11  37.48  38.02   85972640
# 2020-06-09  37.50  37.61  37.22  37.57  105010524
# 2020-06-10  37.88  37.94  37.55  37.59   68975000

# %%
# we can also do weekly prices
# notice that it displays end of the weekend
d_new=df1.asfreq("W", method="pad")
d_new
# Out:
#              Open   High    Low  Close     Volume
# 2020-06-07  37.95  38.46  37.95  38.19   75415720
# 2020-06-14  37.30  37.53  37.17  37.52   71475156
# 2020-06-21  36.18  36.46  36.10  36.38   79127360
# 2020-06-28  36.22  36.33  35.78  35.88   57111400
# 2020-07-05  36.79  37.07  36.35  36.46  102769436
# 2020-07-12  35.92  36.69  35.92  36.59  130165600
# 2020-07-19  36.44  36.52  35.63  36.36  289229312
# 2020-07-26  38.59  38.61  38.37  38.48  101326640
# 2020-08-02  38.50  38.56  38.33  38.40   87710564
# 2020-08-09  38.35  38.50  38.16  38.27  107843156
# 2020-08-16  38.68  39.11  38.67  39.03  130108080
# 2020-08-23  36.69  37.25  36.69  37.24  109310920
# 2020-08-30  36.02  36.08  35.82  35.91   83441436
# 2020-09-06  35.61  35.67  35.46  35.57   69283720
# 2020-09-13  35.48  35.60  35.26  35.26   71291524
# 2020-09-20  36.07  36.13  35.86  35.92   84596116
# 2020-09-27  36.05  36.13  35.88  35.98   84829000
# 2020-10-04  35.32  35.40  35.15  35.23   81385204
# ...

# %%
# we can also do hourly prices
dh=df1.asfreq("H", method="pad")
dh.head(10)
# Out:
#                       Open   High    Low  Close    Volume
# 2020-06-01 00:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 01:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 02:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 03:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 04:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 05:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 06:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 07:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 08:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 09:00:00  37.48  37.58  37.03  37.18  79383680

# %%
# we can also do yearly prices
dh=df1.asfreq("A", method="pad")
dh.head(10)
# Out:
#              Open   High    Low  Close     Volume
# 2020-12-31  28.95  29.35  28.94  29.16  111117680

# %%
# we can also do prices second
dh=df1.asfreq("S", method="pad")
dh.head(10)
# Out:
#                       Open   High    Low  Close    Volume
# 2020-06-01 00:00:00  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:01  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:02  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:03  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:04  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:05  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:06  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:07  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:08  37.48  37.58  37.03  37.18  79383680
# 2020-06-01 00:00:09  37.48  37.58  37.03  37.18  79383680

# %% [markdown]
# # what if i only know the start date but not the end date. I also know the periods (datetime index elements)  want to generate in my range
# Then, specify the start date range and periods.  This is very helpful when you are generating test data,eg unit test, integration test

# %%
# generate the first 80 business days starting from January
nrg=pd.date_range("1/1/2020", periods=80, freq=("B"))
nrg
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-20', '2020-01-21', '2020-01-22',
#                '2020-01-23', '2020-01-24', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-03',
#                '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07',
#                '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13',
#                '2020-02-14', '2020-02-17', '2020-02-18', '2020-02-19',
#                '2020-02-20', '2020-02-21', '2020-02-24', '2020-02-25',
#                '2020-02-26', '2020-02-27', '2020-02-28', '2020-03-02',
#                '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06',
#                '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
# ...

# %%
# generate the first 80 hourly days starting from January
nrg=pd.date_range("1/1/2020", periods=80, freq=("H"))
nrg
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00',
#                '2020-01-01 10:00:00', '2020-01-01 11:00:00',
#                '2020-01-01 12:00:00', '2020-01-01 13:00:00',
#                '2020-01-01 14:00:00', '2020-01-01 15:00:00',
#                '2020-01-01 16:00:00', '2020-01-01 17:00:00',
#                '2020-01-01 18:00:00', '2020-01-01 19:00:00',
#                '2020-01-01 20:00:00', '2020-01-01 21:00:00',
#                '2020-01-01 22:00:00', '2020-01-01 23:00:00',
#                '2020-01-02 00:00:00', '2020-01-02 01:00:00',
#                '2020-01-02 02:00:00', '2020-01-02 03:00:00',
#                '2020-01-02 04:00:00', '2020-01-02 05:00:00',
# ...

# %%
# This is very helpful when you are generating test data,eg unit test, integration test eg
# generate some random integers btn 1 - 10, in the length of my range ie generate basically 80 numbers
import numpy as np
np.random.randint(1,10,len(nrg))
# Out:
# array([5, 4, 9, 1, 6, 6, 7, 3, 4, 1, 9, 8, 4, 5, 1, 8, 5, 7, 9, 6, 9, 8,
#        7, 7, 9, 4, 7, 3, 3, 8, 8, 9, 3, 8, 5, 8, 8, 2, 8, 1, 9, 9, 9, 1,
#        3, 1, 9, 1, 2, 7, 7, 7, 9, 4, 1, 5, 7, 1, 1, 6, 2, 6, 9, 5, 8, 8,
#        1, 2, 7, 2, 7, 5, 6, 9, 1, 6, 6, 8, 6, 4])

# %%
# now generate time series out of this data
ts=pd.Series(np.random.randint(1,10,len(nrg)), index=nrg)
ts.head(10)
# Out:
# 2020-01-01 00:00:00    6
# 2020-01-01 01:00:00    9
# 2020-01-01 02:00:00    3
# 2020-01-01 03:00:00    4
# 2020-01-01 04:00:00    7
# 2020-01-01 05:00:00    2
# 2020-01-01 06:00:00    4
# 2020-01-01 07:00:00    1
# 2020-01-01 08:00:00    1
# 2020-01-01 09:00:00    2
# Freq: H, dtype: int64

# %% [markdown]
# # Handling time holidays in time series analysis and how to create a custom holiday calender and generate datetimeindex out of it

# %%
# read the csv file. Notice that we have no data on 4th of july 2017 coz its a public holiday for US and stocks dont trade
# 
th_df = pd.read_csv("csv_files/aapl/july16_17.csv")
th_df.head(30)
# Out:
#           Date   Open   High    Low  Close       Volume
# 0   07/28/2017  37.47  37.56  37.30  37.38   68,854,600
# 1   07/27/2017  38.44  38.50  36.83  37.64  129,905,360
# 2   07/26/2017  38.34  38.48  38.27  38.37   63,123,800
# 3   07/25/2017  37.95  38.46  37.95  38.19   75,415,720
# 4   07/24/2017  37.65  38.11  37.48  38.02   85,972,640
# 5   07/21/2017  37.50  37.61  37.22  37.57  105,010,524
# 6   07/20/2017  37.88  37.94  37.55  37.59   68,975,000
# 7   07/19/2017  37.62  37.86  37.49  37.76   83,691,884
# 8   07/18/2017  37.30  37.53  37.17  37.52   71,475,156
# 9   07/17/2017  37.21  37.73  37.14  37.39   95,173,844
# 10  07/14/2017  36.99  37.33  36.83  37.26   80,528,244
# 11  07/13/2017  36.38  37.12  36.36  36.94  100,797,476
# 12  07/12/2017  36.47  36.55  36.21  36.44   99,537,920
# 13  07/11/2017  36.18  36.46  36.10  36.38   79,127,360
# 14  07/10/2017  36.03  36.49  35.84  36.27   84,362,564
# 15  07/07/2017  35.73  36.19  35.73  36.05   76,806,844
# ...

# %%
# consider the dataframe below missing dates
df_miss=pd.read_csv("csv_files/aapl/aapl_no_date.csv")
df_miss
# Out:
#      Open   High    Low  Close     Volume
# 0   37.48  37.58  37.03  37.18   79383680
# 1   37.47  37.56  37.30  37.38   68854600
# 2   38.44  38.50  36.83  37.64  129905360
# 3   38.34  38.48  38.27  38.37   63123800
# 4   37.95  38.46  37.95  38.19   75415720
# 5   37.65  38.11  37.48  38.02   85972640
# 6   37.50  37.61  37.22  37.57  105010524
# 7   37.88  37.94  37.55  37.59   68975000
# 8   37.62  37.86  37.49  37.76   83691884
# 9   37.30  37.53  37.17  37.52   71475156
# 10  37.21  37.73  37.14  37.39   95173844
# 11  36.99  37.33  36.83  37.26   80528244
# 12  36.38  37.12  36.36  36.94  100797476
# 13  36.47  36.55  36.21  36.44   99537920

# %%
# consider the following dataframe also
# notice that 2017-07-04 is included and the df wont work coz 4th july is a public holiday
# i want to exclude all the holidays in US
# B does not take into account US holidays
# so we've to use US calendar for this purpose
dfff= pd.date_range(start="7/1/2017", end="7/21/2017",freq="B")
dfff
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
# now import import UsFederalHolidayCalender
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
# create a custom US business day
usb= CustomBusinessDay(calendar=USFederalHolidayCalendar())
usb

# %%
# now use the custom calendar as frequence
# notice that 4th jul is excluded now coz its a holiday
ndr= pd.date_range(start="7/1/2017", end="7/21/2017",freq=usb)
ndr
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='C')

# %%
# we can now set our new date range to our dataframe
# This will exclude weekends and holidays
df_miss.set_index(ndr, inplace=True)
df_miss
# Out:
#              Open   High    Low  Close     Volume
# 2017-07-03  37.48  37.58  37.03  37.18   79383680
# 2017-07-05  37.47  37.56  37.30  37.38   68854600
# 2017-07-06  38.44  38.50  36.83  37.64  129905360
# 2017-07-07  38.34  38.48  38.27  38.37   63123800
# 2017-07-10  37.95  38.46  37.95  38.19   75415720
# 2017-07-11  37.65  38.11  37.48  38.02   85972640
# 2017-07-12  37.50  37.61  37.22  37.57  105010524
# 2017-07-13  37.88  37.94  37.55  37.59   68975000
# 2017-07-14  37.62  37.86  37.49  37.76   83691884
# 2017-07-17  37.30  37.53  37.17  37.52   71475156
# 2017-07-18  37.21  37.73  37.14  37.39   95173844
# 2017-07-19  36.99  37.33  36.83  37.26   80528244
# 2017-07-20  36.38  37.12  36.36  36.94  100797476
# 2017-07-21  36.47  36.55  36.21  36.44   99537920

# %% [markdown]
# # customizing the holiday calendar

# %%
# copy the abstract class for pandas calendar from github
# available at:   https://github.com/pandas-dev/pandas/blob/main/pandas/tseries/holiday.py

# import the necessary classes
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday


class MyBirthDayCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday("Mutungi's Birthday", month=7, day=30, observance=nearest_workday),
    ]

# now custom your own calendar
# execute it to create an instance of MyBirthDayCalendar class
# when you set observance=nearest_workday, then 29th will also be excluded
# holiday cal
# nearest_workday == move sat to fri and sun to mon
# see various values you can supply as observance
mycal = CustomBusinessDay(calendar=MyBirthDayCalendar())
mycal

# %%
# now supply it in the pandas daterange function
# from the output, we can see that 2nd jul and 30th jul are excluded from the data coz they are holidays for Nam and Mutungi
pd.date_range(start="7/1/2020", end="10/30/2020", freq=mycal)
# Out:
# DatetimeIndex(['2020-07-01', '2020-07-02', '2020-07-03', '2020-07-06',
#                '2020-07-07', '2020-07-08', '2020-07-09', '2020-07-10',
#                '2020-07-13', '2020-07-14', '2020-07-15', '2020-07-16',
#                '2020-07-17', '2020-07-20', '2020-07-21', '2020-07-22',
#                '2020-07-23', '2020-07-24', '2020-07-27', '2020-07-28',
#                '2020-07-29', '2020-07-31', '2020-08-03', '2020-08-04',
#                '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-10',
#                '2020-08-11', '2020-08-12', '2020-08-13', '2020-08-14',
#                '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20',
#                '2020-08-21', '2020-08-24', '2020-08-25', '2020-08-26',
#                '2020-08-27', '2020-08-28', '2020-08-31', '2020-09-01',
#                '2020-09-02', '2020-09-03', '2020-09-04', '2020-09-07',
#                '2020-09-08', '2020-09-09', '2020-09-10', '2020-09-11',
# ...

# %% [markdown]
# want to cater for countries where friday and saturday are holidays/weekends eg muslim countries like Egypt

# %%
# we can do this by customizing the CustomBusinessDay's weekmask function
# lets say 29th oct is a holiday, just include it also
egypt = CustomBusinessDay(weekmask="Sun Mon Tue Wed Thu", holidays=["2023-10-29"])
egypt

# %%
# now pass the created custom business days to the dataframe
# the fridays and satardays are now treated as weekend
# notice that days like 6,7, 13,14,20,21,27,28 are excluded and treated as weekends
# also 29th is excluded as a holiday as explicitly made
pd.date_range(start="10/1/2023", end="10/30/2023", freq=egypt)
# Out:
# DatetimeIndex(['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04',
#                '2023-10-05', '2023-10-08', '2023-10-09', '2023-10-10',
#                '2023-10-11', '2023-10-12', '2023-10-15', '2023-10-16',
#                '2023-10-17', '2023-10-18', '2023-10-19', '2023-10-22',
#                '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26',
#                '2023-10-30'],
#               dtype='datetime64[ns]', freq='C')

# %%
# Converting different string date formats to date
dates = ["2017/05/01","2017-05-01","Jan 5, 2017","01/05/2017","2017.01.05","20170105"]
pd.to_datetime(dates, errors="ignore")
# Out:
# Index(['2017/05/01', '2017-05-01', 'Jan 5, 2017', '01/05/2017', '2017.01.05',
#        '20170105'],
#       dtype='object')

# %%
# check if date has been converted
type(pd.to_datetime(dates[5]))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# using epoch time, ie shows the nmber of seconds since Jan 1, 1970 UTC
# set the unit to s ==> seconds coz t represents the number of seconds since jan 1st 1970
t= 1696518081
pd.to_datetime(t, unit="s")
# Out:
# Timestamp('2023-10-05 15:01:21')

# %%
# we can also store it as a DatetieeIndex
dd=pd.to_datetime([t], unit="s")
dd
# Out:
# DatetimeIndex(['2023-10-05 15:01:21'], dtype='datetime64[ns]', freq=None)

# %%
# convert back to epoch
# you get extra zeros coz its set to nanoseconds by default
dd.view("int64")
# Out:
# array([1696518081000000000])

# %% [markdown]
# # Understanding pandas series' timestamp

# %%
# create 2023 yearly period
# A-DEC means the period is annual and ending in december
yr= pd.Period("2023")
yr
# Out:
# Period('2023', 'A-DEC')

# %%
# look at all the propeties of this period
dir(yr)
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_offset',
#  '_add_timedeltalike_scalar',
#  '_dtype',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_require_matching_freq',
#  'asfreq',
#  'day',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
# ...

# %%
# try a few properties
yr.start_time
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
yr.end_time
# Out:
# Timestamp('2023-12-31 23:59:59.999999999')

# %%
# create a monthly time period
m= pd.Period("2023-10", freq="M")
m
# Out:
# Period('2023-10', 'M')

# %%
m.start_time
# Out:
# Timestamp('2023-10-01 00:00:00')

# %%
m.end_time
# Out:
# Timestamp('2023-10-31 23:59:59.999999999')

# %%
# perform maths operations
# will add 1 month to oct
m+2
# Out:
# Period('2023-12', 'M')

# %%
# create a daily time period
# freq is set to day, D by default
d=pd.Period("2023-10-5", freq="D")
d
# Out:
# Period('2023-10-05', 'D')

# %%
# weekly time period
w=pd.Period("2023-02-28", freq="W")
w
# Out:
# Period('2023-02-27/2023-03-05', 'W-SUN')

# %%
# hourly time period
h=pd.Period("2023-10-05 23:00:00", freq="H")
h
# Out:
# Period('2023-10-05 23:00', 'H')

# %%
h.start_time
# Out:
# Timestamp('2023-10-05 23:00:00')

# %%
h.end_time
# Out:
# Timestamp('2023-10-05 23:59:59.999999999')

# %%
# add 1 hr, it will go to 6th oct
h+1
# Out:
# Period('2023-10-06 00:00', 'H')

# %%
# alt we can use offsets
h+pd.offsets.Hour(1)
# Out:
# Period('2023-10-06 00:00', 'H')

# %% [markdown]
# # quarterly time period
# a quarter is normally 3 months

# %%
q1=pd.Period("2023Q1")
q1
# Out:
# Period('2023Q1', 'Q-DEC')

# %%
q1+1
# Out:
# Period('2023Q2', 'Q-DEC')

# %%
q1.start_time
# Out:
# Timestamp('2023-01-01 00:00:00')

# %%
q1.end_time
# Out:
# Timestamp('2023-03-31 23:59:59.999999999')

# %%
# for comps like Walmart whose fiscal year starts from Feb and ends in Jane
q=pd.Period("2023Q1", freq="Q-JAN")
q
# Out:
# Period('2023Q1', 'Q-JAN')

# %%
# this shoews that the fiscal year ends in Jan not Dec
q.start_time
# Out:
# Timestamp('2022-02-01 00:00:00')

# %%
# specify as freq
q.asfreq("M", how="start")
# Out:
# Period('2022-02', 'M')

# %%
q.asfreq("M", how="end")
# Out:
# Period('2022-04', 'M')

# %%
# create periods btn 2016 and 2022
idx= pd.period_range("2016", "2022", freq="Q")
idx
# Out:
# PeriodIndex(['2016Q1', '2016Q2', '2016Q3', '2016Q4', '2017Q1', '2017Q2',
#              '2017Q3', '2017Q4', '2018Q1', '2018Q2', '2018Q3', '2018Q4',
#              '2019Q1', '2019Q2', '2019Q3', '2019Q4', '2020Q1', '2020Q2',
#              '2020Q3', '2020Q4', '2021Q1', '2021Q2', '2021Q3', '2021Q4',
#              '2022Q1'],
#             dtype='period[Q-DEC]')

# %% [markdown]
# # analyse the data of walmart and transpose it adding two quartiles for start date and end tade

# %%
# read the csv
wmt=pd.read_csv("csv_files/aapl/wmt.csv")
wmt
# Out:
#   Line Item  2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# 0   Revenue  115904  120854  118179  130936  117542
# 1  Expenses   86544   89485   87484   97743   87688
# 2    Profit   29360   31369   30695   33193   29854

# %%
# set Line item to index
wmt.set_index("Line Item", inplace=True)
wmt
# Out:
#            2017Q1  2017Q2  2017Q3  2017Q4  2018Q1
# Line Item
# Revenue    115904  120854  118179  130936  117542
# Expenses    86544   89485   87484   97743   87688
# Profit      29360   31369   30695   33193   29854

# %%
# transpose the dataframe ie make rows columns and vice cersa
wmt = wmt.T
wmt
# Out:
# Line Item  Revenue  Expenses  Profit
# 2017Q1      115904     86544   29360
# 2017Q2      120854     89485   31369
# 2017Q3      118179     87484   30695
# 2017Q4      130936     97743   33193
# 2018Q1      117542     87688   29854

# %%
# now convert the indexto period index and set Quratile to Jan.
wmt.index = pd.PeriodIndex(wmt.index, freq="Q-JAN")
wmt.index
# Out:
# PeriodIndex(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='period[Q-JAN]')

# %%
# now create the start date column
# write a function that will use PeriodIndex(['2017Q1', '2017Q2', '2017Q3', '2017Q4', '2018Q1'], dtype='period[Q-JAN]') and 
# return start time from each of these elements.
# do a quick way to define a function by calling lambda
wmt["Start Date"] = wmt.index.map(lambda x: x.start_time)
wmt
# Out:
# Line Item  Revenue  Expenses  Profit Start Date
# 2017Q1      115904     86544   29360 2016-02-01
# 2017Q2      120854     89485   31369 2016-05-01
# 2017Q3      118179     87484   30695 2016-08-01
# 2017Q4      130936     97743   33193 2016-11-01
# 2018Q1      117542     87688   29854 2017-02-01

# %%
# create the end date
wmt["End Date"] = wmt.index.map(lambda x: x.end_time)
wmt
# Out:
# Line Item  Revenue  Expenses  Profit Start Date                      End Date
# 2017Q1      115904     86544   29360 2016-02-01 2016-04-30 23:59:59.999999999
# 2017Q2      120854     89485   31369 2016-05-01 2016-07-31 23:59:59.999999999
# 2017Q3      118179     87484   30695 2016-08-01 2016-10-31 23:59:59.999999999
# 2017Q4      130936     97743   33193 2016-11-01 2017-01-31 23:59:59.999999999
# 2018Q1      117542     87688   29854 2017-02-01 2017-04-30 23:59:59.999999999

# %% [markdown]
# # shifting and lagging
# Shifting can be used to calculate percentage change

# %%
# read fb csv file
fb=pd.read_csv("csv_files/fb.csv")
fb
# Out:
#        Date   Price
# 0  08/15/17  171.00
# 1  08/16/17  170.00
# 2  08/17/17  166.91
# 3  08/18/17  167.41
# 4  08/21/17  167.78
# 5  08/22/17  169.64
# 6  08/23/17  168.71
# 7  08/24/17  167.74
# 8  08/25/17  166.32
# 9  08/28/17  167.24

# %%
fb.set_index("Date", inplace=True)
fb
# Out:
#            Price
# Date
# 08/15/17  171.00
# 08/16/17  170.00
# 08/17/17  166.91
# 08/18/17  167.41
# 08/21/17  167.78
# 08/22/17  169.64
# 08/23/17  168.71
# 08/24/17  167.74
# 08/25/17  166.32
# 08/28/17  167.24

# %%
# now shift the prices by one day
# right shift
# will shift the price of 25th to 26th
fb.shift(1)
# Out:
#            Price
# Date
# 08/15/17     NaN
# 08/16/17  171.00
# 08/17/17  170.00
# 08/18/17  166.91
# 08/21/17  167.41
# 08/22/17  167.78
# 08/23/17  169.64
# 08/24/17  168.71
# 08/25/17  167.74
# 08/28/17  166.32

# %%
# left shifting
# this will shift the price of 16th to 15th
fb.shift(-1)
# Out:
#            Price
# Date
# 08/15/17  170.00
# 08/16/17  166.91
# 08/17/17  167.41
# 08/18/17  167.78
# 08/21/17  169.64
# 08/22/17  168.71
# 08/23/17  167.74
# 08/24/17  166.32
# 08/25/17  167.24
# 08/28/17     NaN

# %%
# lets use shift to calculate price change in one day
# create a column for the previous day
fb["Price for previous day"]= fb["Price"].shift(1)
fb
# Out:
#            Price  Price for previous day
# Date
# 08/15/17  171.00                     NaN
# 08/16/17  170.00                  171.00
# 08/17/17  166.91                  170.00
# 08/18/17  167.41                  166.91
# 08/21/17  167.78                  167.41
# 08/22/17  169.64                  167.78
# 08/23/17  168.71                  169.64
# 08/24/17  167.74                  168.71
# 08/25/17  166.32                  167.74
# 08/28/17  167.24                  166.32

# %%
# now calculate the price change
fb["Price change in 1 day"] = fb["Price"] - fb["Price for previous day"]
fb
# Out:
#            Price  Price for previous day  Price change in 1 day
# Date
# 08/15/17  171.00                     NaN                    NaN
# 08/16/17  170.00                  171.00                  -1.00
# 08/17/17  166.91                  170.00                  -3.09
# 08/18/17  167.41                  166.91                   0.50
# 08/21/17  167.78                  167.41                   0.37
# 08/22/17  169.64                  167.78                   1.86
# 08/23/17  168.71                  169.64                  -0.93
# 08/24/17  167.74                  168.71                  -0.97
# 08/25/17  166.32                  167.74                  -1.42
# 08/28/17  167.24                  166.32                   0.92

# %%
# calculate the five day percentage return
fb["5 day % return"] = (fb["Price"] - fb["Price"].shift(5))*100/fb["Price"].shift(5)
fb
# Out:
#            Price  Price for previous day  Price change in 1 day  \
# Date
# 08/15/17  171.00                     NaN                    NaN
# 08/16/17  170.00                  171.00                  -1.00
# 08/17/17  166.91                  170.00                  -3.09
# 08/18/17  167.41                  166.91                   0.50
# 08/21/17  167.78                  167.41                   0.37
# 08/22/17  169.64                  167.78                   1.86
# 08/23/17  168.71                  169.64                  -0.93
# 08/24/17  167.74                  168.71                  -0.97
# 08/25/17  166.32                  167.74                  -1.42
# 08/28/17  167.24                  166.32                   0.92
#
#           5 day % return
# Date
# 08/15/17             NaN
# 08/16/17             NaN
# 08/17/17             NaN
# 08/18/17             NaN
# 08/21/17             NaN
# 08/22/17       -0.795322
# 08/23/17       -0.758824
# 08/24/17        0.497274
# ...

# %% [markdown]
# There is NaN from 15th to 21st coz there i no price available before Fridays but like for 22nd, we get 169.64-171.00
# to calculate the % return

# %%
# use the date column instead of price
# restore the original df
fb=fb[["Price"]]
fb
# Out:
#            Price
# Date
# 08/15/17  171.00
# 08/16/17  170.00
# 08/17/17  166.91
# 08/18/17  167.41
# 08/21/17  167.78
# 08/22/17  169.64
# 08/23/17  168.71
# 08/24/17  167.74
# 08/25/17  166.32
# 08/28/17  167.24

# %%
# check index
# to shift dates, we ned to use the frequency
# change the df to business days so as to use date for shifting
fb.index = pd.date_range("15-08-2017", periods=10, freq="B")
fb.index
# Out:
# DatetimeIndex(['2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#                '2017-08-21', '2017-08-22', '2017-08-23', '2017-08-24',
#                '2017-08-25', '2017-08-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
# we can now shift the dates and not the data points
# This code will shift the dates in the 'date' column by one position, effectively moving each date one step forward.

# %% [markdown]
# # Handling time zones

# %%
# read Microsoft data file
ms = pd.read_csv("csv_files/msdata.csv", header=1, index_col="Date Time", parse_dates=True)
ms
# Out:
# /tmp/ipykernel_3225/190842999.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ms = pd.read_csv("csv_files/msdata.csv", header=1, index_col="Date Time", parse_dates=True)
#                      Price
# Date Time
# 2017-08-17 09:00:00  72.38
# 2017-08-17 09:15:00  71.00
# 2017-08-17 09:30:00  71.67
# 2017-08-17 10:00:00  72.80
# 2017-08-17 09:30:00  73.00
# 2017-08-17 11:00:00  72.50

# %%
# notice that the date below is a Naive datatime object
ms.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00', '2017-08-17 09:15:00',
#                '2017-08-17 09:30:00', '2017-08-17 10:00:00',
#                '2017-08-17 09:30:00', '2017-08-17 11:00:00'],
#               dtype='datetime64[ns]', name='Date Time', freq=None)

# %%
# There are two types of time zone
# 1. Naive (No timezone awareness). This is the default timezone
# 2. Timezone aware datetime
# change timezone
ms = ms.tz_localize(tz="US/Eastern")
ms
# Out:
#                            Price
# Date Time
# 2017-08-17 09:00:00-04:00  72.38
# 2017-08-17 09:15:00-04:00  71.00
# 2017-08-17 09:30:00-04:00  71.67
# 2017-08-17 10:00:00-04:00  72.80
# 2017-08-17 09:30:00-04:00  73.00
# 2017-08-17 11:00:00-04:00  72.50

# %%
# notice the diff in timezones eg '2017-08-17 09:00:00' and '2017-08-17 09:00:00-04:00'
# this means that US timezone is 4 hours behind the UTC/GMT
ms.index
# Out:
# DatetimeIndex(['2017-08-17 09:00:00-04:00', '2017-08-17 09:15:00-04:00',
#                '2017-08-17 09:30:00-04:00', '2017-08-17 10:00:00-04:00',
#                '2017-08-17 09:30:00-04:00', '2017-08-17 11:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', name='Date Time', freq=None)

# %%
# lets convert the timezone now to time of Berlin, Germany
# notice that its 15:00:00+02:00 ie 15:00:00 in + 2 hrs ie Berlin is 2hrs ahead of GMT
ms = ms.tz_convert(tz="Europe/Berlin")
ms
# Out:
#                            Price
# Date Time
# 2017-08-17 15:00:00+02:00  72.38
# 2017-08-17 15:15:00+02:00  71.00
# 2017-08-17 15:30:00+02:00  71.67
# 2017-08-17 16:00:00+02:00  72.80
# 2017-08-17 15:30:00+02:00  73.00
# 2017-08-17 17:00:00+02:00  72.50

# %%
# Time strings
from pytz import all_timezones
all_timezones
# Out:
# ['Africa/Abidjan',
#  'Africa/Accra',
#  'Africa/Addis_Ababa',
#  'Africa/Algiers',
#  'Africa/Asmara',
#  'Africa/Asmera',
#  'Africa/Bamako',
#  'Africa/Bangui',
#  'Africa/Banjul',
#  'Africa/Bissau',
#  'Africa/Blantyre',
#  'Africa/Brazzaville',
#  'Africa/Bujumbura',
#  'Africa/Cairo',
#  'Africa/Casablanca',
#  'Africa/Ceuta',
#  'Africa/Conakry',
#  'Africa/Dakar',
#  'Africa/Dar_es_Salaam',
#  'Africa/Djibouti',
#  'Africa/Douala',
#  'Africa/El_Aaiun',
#  'Africa/Freetown',
#  'Africa/Gaborone',
#  'Africa/Harare',
#  'Africa/Johannesburg',
#  'Africa/Juba',
#  'Africa/Kampala',
#  'Africa/Khartoum',
#  'Africa/Kigali',
#  'Africa/Kinshasa',
#  'Africa/Lagos',
#  'Africa/Libreville',
#  'Africa/Lome',
#  'Africa/Luanda',
#  'Africa/Lubumbashi',
#  'Africa/Lusaka',
#  'Africa/Malabo',
#  'Africa/Maputo',
#  'Africa/Maseru',
#  'Africa/Mbabane',
#  'Africa/Mogadishu',
#  'Africa/Monrovia',
#  'Africa/Nairobi',
#  'Africa/Ndjamena',
#  'Africa/Niamey',
#  'Africa/Nouakchott',
# ...

# %%
# converting to kampala timezone
# Notice that Kampala is 3hrs ahead of GMT
ms = ms.tz_convert("Africa/Kampala")
ms
# Out:
#                            Price
# Date Time
# 2017-08-17 16:00:00+03:00  72.38
# 2017-08-17 16:15:00+03:00  71.00
# 2017-08-17 16:30:00+03:00  71.67
# 2017-08-17 17:00:00+03:00  72.80
# 2017-08-17 16:30:00+03:00  73.00
# 2017-08-17 18:00:00+03:00  72.50

# %% [markdown]
# # Using timezones in date_range function

# %%
# notice that it creates a Naive datetime object
# supply the timezone function to convert it to Timezone aware datetime
d_range = pd.date_range(start="1/1/2023", periods=10, freq="H", tz="Africa/Kampala")
d_range
# Out:
# DatetimeIndex(['2023-01-01 00:00:00+03:00', '2023-01-01 01:00:00+03:00',
#                '2023-01-01 02:00:00+03:00', '2023-01-01 03:00:00+03:00',
#                '2023-01-01 04:00:00+03:00', '2023-01-01 05:00:00+03:00',
#                '2023-01-01 06:00:00+03:00', '2023-01-01 07:00:00+03:00',
#                '2023-01-01 08:00:00+03:00', '2023-01-01 09:00:00+03:00'],
#               dtype='datetime64[ns, Africa/Kampala]', freq='H')

# %%
# supply the timezone function to convert it to Timezone aware datetime
# using dateutil ie uses the available datetime zones in your OS
d_range = pd.date_range(start="1/1/2023", periods=10, freq="H", tz="dateutil/Africa/Kampala")
d_range
# Out:
# DatetimeIndex(['2023-01-01 00:00:00+03:00', '2023-01-01 01:00:00+03:00',
#                '2023-01-01 02:00:00+03:00', '2023-01-01 03:00:00+03:00',
#                '2023-01-01 04:00:00+03:00', '2023-01-01 05:00:00+03:00',
#                '2023-01-01 06:00:00+03:00', '2023-01-01 07:00:00+03:00',
#                '2023-01-01 08:00:00+03:00', '2023-01-01 09:00:00+03:00'],
#               dtype='datetime64[ns, tzfile('/usr/share/zoneinfo/Africa/Kampala')]', freq='H')

# %%
# Generate another time zone
rng = pd.date_range(start="2023-08-22 09:00:00", periods=10, freq="30min")
s = pd.Series(range(10), index=rng)
s
# Out:
# 2023-08-22 09:00:00    0
# 2023-08-22 09:30:00    1
# 2023-08-22 10:00:00    2
# 2023-08-22 10:30:00    3
# 2023-08-22 11:00:00    4
# 2023-08-22 11:30:00    5
# 2023-08-22 12:00:00    6
# 2023-08-22 12:30:00    7
# 2023-08-22 13:00:00    8
# 2023-08-22 13:30:00    9
# Freq: 30T, dtype: int64

# %%
# convert the timezone to Kampala time
kla = s.tz_localize("Africa/Kampala")
kla
# Out:
# 2023-08-22 09:00:00+03:00    0
# 2023-08-22 09:30:00+03:00    1
# 2023-08-22 10:00:00+03:00    2
# 2023-08-22 10:30:00+03:00    3
# 2023-08-22 11:00:00+03:00    4
# 2023-08-22 11:30:00+03:00    5
# 2023-08-22 12:00:00+03:00    6
# 2023-08-22 12:30:00+03:00    7
# 2023-08-22 13:00:00+03:00    8
# 2023-08-22 13:30:00+03:00    9
# dtype: int64

# %%
kla.index
# Out:
# DatetimeIndex(['2023-08-22 09:00:00+03:00', '2023-08-22 09:30:00+03:00',
#                '2023-08-22 10:00:00+03:00', '2023-08-22 10:30:00+03:00',
#                '2023-08-22 11:00:00+03:00', '2023-08-22 11:30:00+03:00',
#                '2023-08-22 12:00:00+03:00', '2023-08-22 12:30:00+03:00',
#                '2023-08-22 13:00:00+03:00', '2023-08-22 13:30:00+03:00'],
#               dtype='datetime64[ns, Africa/Kampala]', freq=None)

# %%
# convert timezone to Kigali time
rd = s.tz_localize("Africa/Kigali")
rd
# Out:
# 2023-08-22 09:00:00+02:00    0
# 2023-08-22 09:30:00+02:00    1
# 2023-08-22 10:00:00+02:00    2
# 2023-08-22 10:30:00+02:00    3
# 2023-08-22 11:00:00+02:00    4
# 2023-08-22 11:30:00+02:00    5
# 2023-08-22 12:00:00+02:00    6
# 2023-08-22 12:30:00+02:00    7
# 2023-08-22 13:00:00+02:00    8
# 2023-08-22 13:30:00+02:00    9
# dtype: int64

# %%
rd.index[0]
# Out:
# Timestamp('2023-08-22 09:00:00+0200', tz='Africa/Kigali')

# %%
# Now that we have Kampala and Kigali time zones, we can do some calculations
# this will convert both idividual times to a universal UTC timezone and then perform the maths, then try to align the data points
# this will do the maths where the times are the same
kla + rd
# Out:
# 2023-08-22 06:00:00+00:00     NaN
# 2023-08-22 06:30:00+00:00     NaN
# 2023-08-22 07:00:00+00:00     2.0
# 2023-08-22 07:30:00+00:00     4.0
# 2023-08-22 08:00:00+00:00     6.0
# 2023-08-22 08:30:00+00:00     8.0
# 2023-08-22 09:00:00+00:00    10.0
# 2023-08-22 09:30:00+00:00    12.0
# 2023-08-22 10:00:00+00:00    14.0
# 2023-08-22 10:30:00+00:00    16.0
# 2023-08-22 11:00:00+00:00     NaN
# 2023-08-22 11:30:00+00:00     NaN
# dtype: float64
